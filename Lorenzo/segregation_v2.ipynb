# %% [markdown]
# # Simulazione Dinamica di Segregazione
#
# Per studiare l'emergere della polarizzazione dalle scelte individuali dei singoli nodi, abbiamo realizzato una simulazione basata sul **Schelling Segregation Model**.
#
# Il modello parte da una rete random che mantiene la nostra distribuzione di grado e ne fa evolvere gli archi, in modo da non alterare i gradi dei singoli nodi.
#
# Ad ogni step ogni nodo della rete valuta di cambiare un proprio link quando la frazione di nodi simili a cui è connesso è minore della soglia di soddisfazione. Quindi cercherà un nodo simile e disponibile a cui connettersi.
#
# Per mantenere inalterata la distribuzione di grado l'operazione di rewire può essere schematizzata come segue:
#
# $$
# (A,B);(C,D) \implies (A,C);(B,D)
# $$
#
# I nodi $A, B, C, D$ sono scelti rispettando i criteri:
# - $A$ è un nodo **insoddisfatto**
# - $B$ è connesso ad $A$, ma appartenente ad una **classe diversa**
# - $C$ non è connesso ad $A$, ma appartenente alla **stessa classe** di $A$
# - $D$ è un nodo generico connesso con $C$, ma **non connesso** a $B$
#
# ---
#
# **Domande di ricerca:**
# - *Questo modello è in grado di riprodurre i valori di polarizzazione osservati nella rete?*
# - *Per quali valori della soglia di soddisfazione i parametri, che misurano la polarizzazione della rete, raggiungono i valori osservati?*
# - *Si osserva la tendenza dei nodi a dividersi in gruppi separati, anche per soglie di soddisfazione fortemente minori del 50%?*
# - *Come si confronta la simulazione rispetto a un null model Erdős-Rényi con le stesse proprietà topologiche?*

# %%
import igraph as ig
import numpy as np
import matplotlib.pyplot as plt
import json
from sys import stdout

from segregation_model import segregation_sim, satisfaction
from lorenzo_utils import *


THRESHOLD = 0.95      # soglia di soddisfazione
MAX_SATISFACTION = 0.98  # criterio di arresto della simulazione
GRAPH_FILE = 'immigration_23.graphml'
OUT_PATH = f'dump_segregation_{GRAPH_FILE.replace(".graphml","")}_{int(THRESHOLD*100)}.json'

# %%
G = load_graph(DATA_DIR + GRAPH_FILE)

# Mappatura binaria dei gruppi (A=1, altri=0)
attr_map = np.array(G.vs['group'])
nodes = nodes_all(G)
nodes_satisfaction = np.array([
    satisfaction(n, G.neighbors(n), G.vs['group']) for n in nodes
])

n_nodes = G.vcount()
n_edges = G.ecount()
p_er    = n_edges / (n_nodes * (n_nodes - 1) / 2)   # probabilità per ER

# Composizione delle comunità (per assegnazione random proporzionale)
unique_groups, group_counts = np.unique(attr_map, return_counts=True)

# %% [markdown]
# ## Metriche osservate sulla rete reale
#
# Per visualizzare lo stato della simulazione abbiamo usato quattro metriche:
# - **EI index**: ${i_A + i_B -e \over i_A + i_B + e}$
#
#     dove $i_A, i_B$ sono i link interni alle comunità e $e$ sono i link ponte tra le comunità
#
# - **cross fraction**: frazione di link tra comunità rispetto ai link totali della rete
#
# - **satisfaction rate**: frazione dei nodi soddisfatti in accordo con la soglia selezionata in partenza
#
# - **segregation index**: frazione media di nodi simili per ogni nodo

# %%
ei_obs               = ei_index(G, attr_map)
cross_fraction_obs   = 1 - cross_type_fraction(G, attr_map)
satisfaction_rate_obs = nodes_satisfaction[nodes_satisfaction >= THRESHOLD].size / nodes.size
segregation_index_obs = np.mean(nodes_satisfaction)

observed = {
    'ei_index':          ei_obs,
    'cross_fraction':    cross_fraction_obs,
    'satisfaction_rate': satisfaction_rate_obs,
    'segregation_index': segregation_index_obs,
}

print('Valori osservati sulla rete reale (target simulazione):')
for k, v in observed.items():
    print(f'  {k:25s}: {v:.4f}')
# Out:
# Valori osservati sulla rete reale (target simulazione):
#   ei_index                 : -0.9340
#   cross_fraction           : 0.9670
#   satisfaction_rate        : 0.9120
#   segregation_index        : 0.9771

# %% [markdown]
# ## Simulazione sulla rete reale (config. random iniziale)
#
# La funzione `segregation_sim` crea internamente una rete random che preserva la distribuzione di grado della rete reale, poi la fa evolvere secondo il modello di Schelling.

# %%
def run_simulation(G_input, threshold, max_satisfaction=MAX_SATISFACTION, label='sim', savefile_graphml=''):
    """Esegue la simulazione di segregazione e raccoglie le metriche ad ogni step.

    G_input         : grafo igraph di partenza (viene usato internamente da segregation_sim)
    threshold       : soglia di soddisfazione
    max_satisfaction: criterio di stop
    label           : etichetta per il log
    
    Return: dizionario con le serie temporali delle quattro metriche
    """
    results = {k: [] for k in observed}
    statistic = None

    print(f'[{label}] target : EI = {ei_obs:.4f}   Cross fraction = {cross_fraction_obs:.4f}\n')
    stdout.flush()

    for G_sim, statistic in segregation_sim(G_input, threshold, max_satisfaction=max_satisfaction):
        results['ei_index'].append(ei_index(G_sim, attr_map))
        results['cross_fraction'].append(1 - cross_type_fraction(G_sim, attr_map))
        results['satisfaction_rate'].append(statistic['satisfaction_rate'])
        results['segregation_index'].append(statistic['segregation_index'])

        if statistic['i_step']:
            print(f'[{label}] Step {statistic["i_step"]} \n '
                  f'Changed: {statistic["nodes_changed_step"]}  '
                  f'Satisfaction: {statistic["satisfaction_rate"]:.4f}  '
                  f'Index: {statistic["segregation_index"]:.4f}')
        else:
            print(f'[{label}] Simulazione avviata: ', end=' ')

        print(f'EI = {results["ei_index"][-1]:.4f}   '
              f'Cross fraction = {results["cross_fraction"][-1]:.4f}\n')
        stdout.flush()

    if statistic and not statistic['nodes_changed_step']:
        print(f'[{label}] Simulazione terminata in configurazione stabile al passo {statistic["i_step"]}')
        print(f'[{label}] Fallimenti totali: {len(list(filter(lambda x: x > 0, statistic["nodes_failures"])))}')
    else:
        print(f'[{label}] Simulazione fermata a satisfaction rate: {statistic["satisfaction_rate"]*100:.1f}%')
    
    if savefile_graphml:
        G_sim.write_graphml(savefile_graphml)
    return results

# %%
# Perché non mettere max_satisfaction=satisfaction_rate_obs?
results_real = run_simulation(G, THRESHOLD, label='rete reale', savefile_graphml=f'segregation_{THRESHOLD*100}_2.graphml', max_satisfaction=satisfaction_rate_obs)
# Out:
# [rete reale] target : EI = -0.9340   Cross fraction = 0.9670
#
# [rete reale] Simulazione avviata:  EI = -0.0206   Cross fraction = 0.5103
#
# [rete reale] Step 1
#  Changed: 6229  Satisfaction: 0.3456  Index: 0.5729
# EI = -0.2320   Cross fraction = 0.6160
#
# [rete reale] Step 2
#  Changed: 4204  Satisfaction: 0.5584  Index: 0.7764
# EI = -0.3067   Cross fraction = 0.6533
#
# [rete reale] Step 3
#  Changed: 3522  Satisfaction: 0.6300  Index: 0.8301
# EI = -0.3538   Cross fraction = 0.6769
#
# [rete reale] Step 4
#  Changed: 3160  Satisfaction: 0.6680  Index: 0.8569
# EI = -0.3852   Cross fraction = 0.6926
#
# [rete reale] Step 5
#  Changed: 2930  Satisfaction: 0.6922  Index: 0.8716
# EI = -0.4133   Cross fraction = 0.7066
#
# [rete reale] Step 6
#  Changed: 2744  Satisfaction: 0.7117  Index: 0.8855
# EI = -0.4343   Cross fraction = 0.7172
#
# [rete reale] Step 7
#  Changed: 2597  Satisfaction: 0.7272  Index: 0.8957
# EI = -0.4560   Cross fraction = 0.7280
#
# [rete reale] Step 8
#  Changed: 2501  Satisfaction: 0.7373  Index: 0.9024
# EI = -0.4718   Cross fraction = 0.7359
#
# [rete reale] Step 9
#  Changed: 2407  Satisfaction: 0.7471  Index: 0.9063
# EI = -0.4873   Cross fraction = 0.7437
#
# [rete reale] Step 10
#  Changed: 2251  Satisfaction: 0.7635  Index: 0.9175
# EI = -0.5027   Cross fraction = 0.7514
#
# [rete reale] Step 11
#  Changed: 2251  Satisfaction: 0.7635  Index: 0.9164
# EI = -0.5147   Cross fraction = 0.7573
#
# [rete reale] Step 12
#  Changed: 2127  Satisfaction: 0.7766  Index: 0.9248
# EI = -0.5277   Cross fraction = 0.7638
#
# [rete reale] Step 13
#  Changed: 2123  Satisfaction: 0.7770  Index: 0.9230
# EI = -0.5385   Cross fraction = 0.7693
#
# [rete reale] Step 14
#  Changed: 2050  Satisfaction: 0.7846  Index: 0.9258
# EI = -0.5467   Cross fraction = 0.7734
#
# [rete reale] Step 15
#  Changed: 1959  Satisfaction: 0.7942  Index: 0.9301
# EI = -0.5555   Cross fraction = 0.7778
#
# [rete reale] Step 16
#  Changed: 1996  Satisfaction: 0.7903  Index: 0.9296
# EI = -0.5634   Cross fraction = 0.7817
#
# [rete reale] Step 17
#  Changed: 1925  Satisfaction: 0.7978  Index: 0.9346
# EI = -0.5720   Cross fraction = 0.7860
#
# [rete reale] Step 18
#  Changed: 1909  Satisfaction: 0.7995  Index: 0.9334
# EI = -0.5785   Cross fraction = 0.7893
#
# [rete reale] Step 19
#  Changed: 1914  Satisfaction: 0.7989  Index: 0.9345
# EI = -0.5860   Cross fraction = 0.7930
#
# [rete reale] Step 20
#  Changed: 1841  Satisfaction: 0.8066  Index: 0.9383
# EI = -0.5919   Cross fraction = 0.7959
#
# [rete reale] Step 21
#  Changed: 1838  Satisfaction: 0.8069  Index: 0.9396
# EI = -0.5980   Cross fraction = 0.7990
#
# [rete reale] Step 22
#  Changed: 1811  Satisfaction: 0.8097  Index: 0.9408
# EI = -0.6047   Cross fraction = 0.8023
#
# [rete reale] Step 23
#  Changed: 1700  Satisfaction: 0.8214  Index: 0.9443
# EI = -0.6110   Cross fraction = 0.8055
#
# [rete reale] Step 24
#  Changed: 1738  Satisfaction: 0.8174  Index: 0.9404
# EI = -0.6167   Cross fraction = 0.8083
#
# [rete reale] Step 25
#  Changed: 1738  Satisfaction: 0.8174  Index: 0.9421
# EI = -0.6209   Cross fraction = 0.8105
#
# [rete reale] Step 26
#  Changed: 1727  Satisfaction: 0.8186  Index: 0.9430
# EI = -0.6261   Cross fraction = 0.8131
#
# [rete reale] Step 27
#  Changed: 1712  Satisfaction: 0.8201  Index: 0.9459
# EI = -0.6312   Cross fraction = 0.8156
#
# [rete reale] Step 28
#  Changed: 1718  Satisfaction: 0.8195  Index: 0.9457
# EI = -0.6366   Cross fraction = 0.8183
#
# [rete reale] Step 29
#  Changed: 1652  Satisfaction: 0.8265  Index: 0.9461
# EI = -0.6405   Cross fraction = 0.8203
#
# [rete reale] Step 30
#  Changed: 1615  Satisfaction: 0.8303  Index: 0.9488
# EI = -0.6455   Cross fraction = 0.8228
#
# [rete reale] Step 31
#  Changed: 1652  Satisfaction: 0.8265  Index: 0.9462
# EI = -0.6494   Cross fraction = 0.8247
#
# [rete reale] Step 32
#  Changed: 1596  Satisfaction: 0.8323  Index: 0.9499
# EI = -0.6538   Cross fraction = 0.8269
#
# [rete reale] Step 33
#  Changed: 1596  Satisfaction: 0.8323  Index: 0.9486
# EI = -0.6574   Cross fraction = 0.8287
#
# [rete reale] Step 34
#  Changed: 1599  Satisfaction: 0.8320  Index: 0.9491
# EI = -0.6609   Cross fraction = 0.8305
#
# [rete reale] Step 35
#  Changed: 1562  Satisfaction: 0.8359  Index: 0.9502
# EI = -0.6642   Cross fraction = 0.8321
#
# [rete reale] Step 36
#  Changed: 1545  Satisfaction: 0.8377  Index: 0.9520
# EI = -0.6670   Cross fraction = 0.8335
#
# [rete reale] Step 37
#  Changed: 1567  Satisfaction: 0.8354  Index: 0.9512
# EI = -0.6710   Cross fraction = 0.8355
#
# [rete reale] Step 38
#  Changed: 1546  Satisfaction: 0.8376  Index: 0.9518
# EI = -0.6734   Cross fraction = 0.8367
#
# [rete reale] Step 39
#  Changed: 1543  Satisfaction: 0.8379  Index: 0.9541
# EI = -0.6763   Cross fraction = 0.8382
#
# [rete reale] Step 40
#  Changed: 1506  Satisfaction: 0.8418  Index: 0.9545
# EI = -0.6787   Cross fraction = 0.8394
#
# [rete reale] Step 41
#  Changed: 1566  Satisfaction: 0.8355  Index: 0.9518
# EI = -0.6819   Cross fraction = 0.8409
#
# [rete reale] Step 42
#  Changed: 1498  Satisfaction: 0.8426  Index: 0.9543
# EI = -0.6855   Cross fraction = 0.8428
#
# [rete reale] Step 43
#  Changed: 1483  Satisfaction: 0.8442  Index: 0.9545
# EI = -0.6889   Cross fraction = 0.8445
#
# [rete reale] Step 44
#  Changed: 1447  Satisfaction: 0.8480  Index: 0.9563
# EI = -0.6915   Cross fraction = 0.8458
#
# [rete reale] Step 45
#  Changed: 1432  Satisfaction: 0.8496  Index: 0.9563
# EI = -0.6935   Cross fraction = 0.8467
#
# [rete reale] Step 46
#  Changed: 1428  Satisfaction: 0.8500  Index: 0.9568
# EI = -0.6962   Cross fraction = 0.8481
#
# [rete reale] Step 47
#  Changed: 1445  Satisfaction: 0.8482  Index: 0.9567
# EI = -0.6994   Cross fraction = 0.8497
#
# [rete reale] Step 48
#  Changed: 1450  Satisfaction: 0.8477  Index: 0.9569
# EI = -0.7016   Cross fraction = 0.8508
#
# [rete reale] Step 49
#  Changed: 1381  Satisfaction: 0.8549  Index: 0.9582
# EI = -0.7032   Cross fraction = 0.8516
#
# [rete reale] Step 50
#  Changed: 1380  Satisfaction: 0.8550  Index: 0.9605
# EI = -0.7059   Cross fraction = 0.8530
#
# [rete reale] Step 51
#  Changed: 1409  Satisfaction: 0.8520  Index: 0.9585
# EI = -0.7085   Cross fraction = 0.8543
#
# [rete reale] Step 52
#  Changed: 1366  Satisfaction: 0.8565  Index: 0.9598
# EI = -0.7106   Cross fraction = 0.8553
#
# [rete reale] Step 53
#  Changed: 1397  Satisfaction: 0.8532  Index: 0.9580
# EI = -0.7128   Cross fraction = 0.8564
#
# [rete reale] Step 54
#  Changed: 1363  Satisfaction: 0.8568  Index: 0.9602
# EI = -0.7151   Cross fraction = 0.8576
#
# [rete reale] Step 55
#  Changed: 1387  Satisfaction: 0.8543  Index: 0.9594
# EI = -0.7163   Cross fraction = 0.8582
#
# [rete reale] Step 56
#  Changed: 1397  Satisfaction: 0.8532  Index: 0.9590
# EI = -0.7193   Cross fraction = 0.8596
#
# [rete reale] Step 57
#  Changed: 1346  Satisfaction: 0.8586  Index: 0.9612
# EI = -0.7213   Cross fraction = 0.8607
#
# [rete reale] Step 58
#  Changed: 1361  Satisfaction: 0.8570  Index: 0.9622
# EI = -0.7226   Cross fraction = 0.8613
#
# [rete reale] Step 59
#  Changed: 1343  Satisfaction: 0.8589  Index: 0.9606
# EI = -0.7248   Cross fraction = 0.8624
#
# [rete reale] Step 60
#  Changed: 1370  Satisfaction: 0.8561  Index: 0.9616
# EI = -0.7275   Cross fraction = 0.8638
#
# [rete reale] Step 61
#  Changed: 1368  Satisfaction: 0.8563  Index: 0.9617
# EI = -0.7290   Cross fraction = 0.8645
#
# [rete reale] Step 62
#  Changed: 1311  Satisfaction: 0.8623  Index: 0.9623
# EI = -0.7314   Cross fraction = 0.8657
#
# [rete reale] Step 63
#  Changed: 1373  Satisfaction: 0.8558  Index: 0.9600
# EI = -0.7330   Cross fraction = 0.8665
#
# [rete reale] Step 64
#  Changed: 1298  Satisfaction: 0.8636  Index: 0.9633
# EI = -0.7352   Cross fraction = 0.8676
#
# [rete reale] Step 65
#  Changed: 1263  Satisfaction: 0.8673  Index: 0.9654
# EI = -0.7366   Cross fraction = 0.8683
#
# [rete reale] Step 66
#  Changed: 1283  Satisfaction: 0.8652  Index: 0.9630
# EI = -0.7382   Cross fraction = 0.8691
#
# [rete reale] Step 67
#  Changed: 1285  Satisfaction: 0.8650  Index: 0.9637
# EI = -0.7398   Cross fraction = 0.8699
#
# [rete reale] Step 68
#  Changed: 1283  Satisfaction: 0.8652  Index: 0.9654
# EI = -0.7411   Cross fraction = 0.8705
#
# [rete reale] Step 69
#  Changed: 1298  Satisfaction: 0.8636  Index: 0.9648
# EI = -0.7433   Cross fraction = 0.8717
#
# [rete reale] Step 70
#  Changed: 1255  Satisfaction: 0.8682  Index: 0.9664
# EI = -0.7447   Cross fraction = 0.8724
#
# [rete reale] Step 71
#  Changed: 1313  Satisfaction: 0.8621  Index: 0.9634
# EI = -0.7471   Cross fraction = 0.8736
#
# [rete reale] Step 72
#  Changed: 1255  Satisfaction: 0.8682  Index: 0.9644
# EI = -0.7485   Cross fraction = 0.8743
#
# [rete reale] Step 73
#  Changed: 1231  Satisfaction: 0.8707  Index: 0.9658
# EI = -0.7496   Cross fraction = 0.8748
#
# [rete reale] Step 74
#  Changed: 1283  Satisfaction: 0.8652  Index: 0.9651
# EI = -0.7518   Cross fraction = 0.8759
#
# [rete reale] Step 75
#  Changed: 1280  Satisfaction: 0.8655  Index: 0.9644
# EI = -0.7533   Cross fraction = 0.8767
#
# [rete reale] Step 76
#  Changed: 1238  Satisfaction: 0.8699  Index: 0.9670
# EI = -0.7543   Cross fraction = 0.8771
#
# [rete reale] Step 77
#  Changed: 1283  Satisfaction: 0.8652  Index: 0.9645
# EI = -0.7559   Cross fraction = 0.8780
#
# [rete reale] Step 78
#  Changed: 1259  Satisfaction: 0.8677  Index: 0.9649
# EI = -0.7574   Cross fraction = 0.8787
#
# [rete reale] Step 79
#  Changed: 1215  Satisfaction: 0.8724  Index: 0.9656
# EI = -0.7590   Cross fraction = 0.8795
#
# [rete reale] Step 80
#  Changed: 1232  Satisfaction: 0.8706  Index: 0.9660
# EI = -0.7604   Cross fraction = 0.8802
#
# [rete reale] Step 81
#  Changed: 1258  Satisfaction: 0.8678  Index: 0.9639
# EI = -0.7616   Cross fraction = 0.8808
#
# [rete reale] Step 82
#  Changed: 1221  Satisfaction: 0.8717  Index: 0.9668
# EI = -0.7631   Cross fraction = 0.8815
#
# [rete reale] Step 83
#  Changed: 1224  Satisfaction: 0.8714  Index: 0.9681
# EI = -0.7650   Cross fraction = 0.8825
#
# [rete reale] Step 84
#  Changed: 1173  Satisfaction: 0.8768  Index: 0.9665
# EI = -0.7663   Cross fraction = 0.8832
#
# [rete reale] Step 85
#  Changed: 1170  Satisfaction: 0.8771  Index: 0.9688
# EI = -0.7676   Cross fraction = 0.8838
#
# [rete reale] Step 86
#  Changed: 1198  Satisfaction: 0.8741  Index: 0.9671
# EI = -0.7691   Cross fraction = 0.8846
#
# [rete reale] Step 87
#  Changed: 1187  Satisfaction: 0.8753  Index: 0.9688
# EI = -0.7703   Cross fraction = 0.8852
#
# [rete reale] Step 88
#  Changed: 1233  Satisfaction: 0.8705  Index: 0.9658
# EI = -0.7720   Cross fraction = 0.8860
#
# [rete reale] Step 89
#  Changed: 1206  Satisfaction: 0.8733  Index: 0.9668
# EI = -0.7739   Cross fraction = 0.8870
#
# [rete reale] Step 90
#  Changed: 1164  Satisfaction: 0.8777  Index: 0.9670
# EI = -0.7751   Cross fraction = 0.8876
#
# [rete reale] Step 91
#  Changed: 1156  Satisfaction: 0.8786  Index: 0.9693
# EI = -0.7764   Cross fraction = 0.8882
#
# [rete reale] Step 92
#  Changed: 1183  Satisfaction: 0.8757  Index: 0.9671
# EI = -0.7776   Cross fraction = 0.8888
#
# [rete reale] Step 93
#  Changed: 1167  Satisfaction: 0.8774  Index: 0.9700
# EI = -0.7789   Cross fraction = 0.8895
#
# [rete reale] Step 94
#  Changed: 1132  Satisfaction: 0.8811  Index: 0.9701
# EI = -0.7805   Cross fraction = 0.8903
#
# [rete reale] Step 95
#  Changed: 1168  Satisfaction: 0.8773  Index: 0.9693
# EI = -0.7814   Cross fraction = 0.8907
#
# [rete reale] Step 96
#  Changed: 1123  Satisfaction: 0.8820  Index: 0.9694
# EI = -0.7826   Cross fraction = 0.8913
#
# [rete reale] Step 97
#  Changed: 1135  Satisfaction: 0.8808  Index: 0.9692
# EI = -0.7832   Cross fraction = 0.8916
#
# [rete reale] Step 98
#  Changed: 1137  Satisfaction: 0.8806  Index: 0.9687
# EI = -0.7839   Cross fraction = 0.8919
#
# [rete reale] Step 99
#  Changed: 1132  Satisfaction: 0.8811  Index: 0.9692
# EI = -0.7850   Cross fraction = 0.8925
#
# [rete reale] Step 100
#  Changed: 1156  Satisfaction: 0.8786  Index: 0.9685
# EI = -0.7861   Cross fraction = 0.8930
#
# [rete reale] Step 101
#  Changed: 1107  Satisfaction: 0.8837  Index: 0.9707
# EI = -0.7874   Cross fraction = 0.8937
#
# [rete reale] Step 102
#  Changed: 1063  Satisfaction: 0.8883  Index: 0.9721
# EI = -0.7880   Cross fraction = 0.8940
#
# [rete reale] Step 103
#  Changed: 1109  Satisfaction: 0.8835  Index: 0.9677
# EI = -0.7892   Cross fraction = 0.8946
#
# [rete reale] Step 104
#  Changed: 1070  Satisfaction: 0.8876  Index: 0.9705
# EI = -0.7912   Cross fraction = 0.8956
#
# [rete reale] Step 105
#  Changed: 1099  Satisfaction: 0.8845  Index: 0.9695
# EI = -0.7920   Cross fraction = 0.8960
#
# [rete reale] Step 106
#  Changed: 1106  Satisfaction: 0.8838  Index: 0.9706
# EI = -0.7929   Cross fraction = 0.8964
#
# [rete reale] Step 107
#  Changed: 1098  Satisfaction: 0.8847  Index: 0.9714
# EI = -0.7941   Cross fraction = 0.8970
#
# [rete reale] Step 108
#  Changed: 1091  Satisfaction: 0.8854  Index: 0.9713
# EI = -0.7955   Cross fraction = 0.8977
#
# [rete reale] Step 109
#  Changed: 1094  Satisfaction: 0.8851  Index: 0.9711
# EI = -0.7964   Cross fraction = 0.8982
#
# [rete reale] Step 110
#  Changed: 1112  Satisfaction: 0.8832  Index: 0.9700
# EI = -0.7974   Cross fraction = 0.8987
#
# [rete reale] Step 111
#  Changed: 1070  Satisfaction: 0.8876  Index: 0.9715
# EI = -0.7985   Cross fraction = 0.8993
#
# [rete reale] Step 112
#  Changed: 1076  Satisfaction: 0.8870  Index: 0.9719
# EI = -0.7997   Cross fraction = 0.8999
#
# [rete reale] Step 113
#  Changed: 1058  Satisfaction: 0.8889  Index: 0.9738
# EI = -0.8005   Cross fraction = 0.9002
#
# [rete reale] Step 114
#  Changed: 1016  Satisfaction: 0.8933  Index: 0.9733
# EI = -0.8012   Cross fraction = 0.9006
#
# [rete reale] Step 115
#  Changed: 1066  Satisfaction: 0.8880  Index: 0.9737
# EI = -0.8024   Cross fraction = 0.9012
#
# [rete reale] Step 116
#  Changed: 1030  Satisfaction: 0.8918  Index: 0.9736
# EI = -0.8033   Cross fraction = 0.9017
#
# [rete reale] Step 117
#  Changed: 1054  Satisfaction: 0.8893  Index: 0.9739
# EI = -0.8044   Cross fraction = 0.9022
#
# [rete reale] Step 118
#  Changed: 1043  Satisfaction: 0.8904  Index: 0.9734
# EI = -0.8054   Cross fraction = 0.9027
#
# [rete reale] Step 119
#  Changed: 1049  Satisfaction: 0.8898  Index: 0.9722
# EI = -0.8057   Cross fraction = 0.9028
#
# [rete reale] Step 120
#  Changed: 1035  Satisfaction: 0.8913  Index: 0.9742
# EI = -0.8061   Cross fraction = 0.9031
#
# [rete reale] Step 121
#  Changed: 1026  Satisfaction: 0.8922  Index: 0.9730
# EI = -0.8072   Cross fraction = 0.9036
#
# [rete reale] Step 122
#  Changed: 1052  Satisfaction: 0.8895  Index: 0.9729
# EI = -0.8084   Cross fraction = 0.9042
#
# [rete reale] Step 123
#  Changed: 1043  Satisfaction: 0.8904  Index: 0.9750
# EI = -0.8097   Cross fraction = 0.9048
#
# [rete reale] Step 124
#  Changed: 1042  Satisfaction: 0.8905  Index: 0.9730
# EI = -0.8101   Cross fraction = 0.9051
#
# [rete reale] Step 125
#  Changed: 1054  Satisfaction: 0.8893  Index: 0.9722
# EI = -0.8110   Cross fraction = 0.9055
#
# [rete reale] Step 126
#  Changed: 1035  Satisfaction: 0.8913  Index: 0.9722
# EI = -0.8119   Cross fraction = 0.9059
#
# [rete reale] Step 127
#  Changed: 1034  Satisfaction: 0.8914  Index: 0.9737
# EI = -0.8130   Cross fraction = 0.9065
#
# [rete reale] Step 128
#  Changed: 1045  Satisfaction: 0.8902  Index: 0.9728
# EI = -0.8144   Cross fraction = 0.9072
#
# [rete reale] Step 129
#  Changed: 995  Satisfaction: 0.8955  Index: 0.9746
# EI = -0.8149   Cross fraction = 0.9075
#
# [rete reale] Step 130
#  Changed: 986  Satisfaction: 0.8964  Index: 0.9740
# EI = -0.8157   Cross fraction = 0.9078
#
# [rete reale] Step 131
#  Changed: 1008  Satisfaction: 0.8941  Index: 0.9742
# EI = -0.8160   Cross fraction = 0.9080
#
# [rete reale] Step 132
#  Changed: 1038  Satisfaction: 0.8910  Index: 0.9731
# EI = -0.8170   Cross fraction = 0.9085
#
# [rete reale] Step 133
#  Changed: 1002  Satisfaction: 0.8947  Index: 0.9748
# EI = -0.8176   Cross fraction = 0.9088
#
# [rete reale] Step 134
#  Changed: 1018  Satisfaction: 0.8931  Index: 0.9733
# EI = -0.8178   Cross fraction = 0.9089
#
# [rete reale] Step 135
#  Changed: 1012  Satisfaction: 0.8937  Index: 0.9741
# EI = -0.8185   Cross fraction = 0.9092
#
# [rete reale] Step 136
#  Changed: 1023  Satisfaction: 0.8925  Index: 0.9730
# EI = -0.8189   Cross fraction = 0.9095
#
# [rete reale] Step 137
#  Changed: 1011  Satisfaction: 0.8938  Index: 0.9734
# EI = -0.8197   Cross fraction = 0.9098
#
# [rete reale] Step 138
#  Changed: 986  Satisfaction: 0.8964  Index: 0.9751
# EI = -0.8204   Cross fraction = 0.9102
#
# [rete reale] Step 139
#  Changed: 1004  Satisfaction: 0.8945  Index: 0.9738
# EI = -0.8215   Cross fraction = 0.9108
#
# [rete reale] Step 140
#  Changed: 983  Satisfaction: 0.8967  Index: 0.9752
# EI = -0.8221   Cross fraction = 0.9110
#
# [rete reale] Step 141
#  Changed: 989  Satisfaction: 0.8961  Index: 0.9745
# EI = -0.8229   Cross fraction = 0.9115
#
# [rete reale] Step 142
#  Changed: 977  Satisfaction: 0.8974  Index: 0.9738
# EI = -0.8237   Cross fraction = 0.9118
#
# [rete reale] Step 143
#  Changed: 1016  Satisfaction: 0.8933  Index: 0.9722
# EI = -0.8242   Cross fraction = 0.9121
#
# [rete reale] Step 144
#  Changed: 982  Satisfaction: 0.8968  Index: 0.9744
# EI = -0.8248   Cross fraction = 0.9124
#
# [rete reale] Step 145
#  Changed: 992  Satisfaction: 0.8958  Index: 0.9748
# EI = -0.8253   Cross fraction = 0.9127
#
# [rete reale] Step 146
#  Changed: 992  Satisfaction: 0.8958  Index: 0.9735
# EI = -0.8262   Cross fraction = 0.9131
#
# [rete reale] Step 147
#  Changed: 1009  Satisfaction: 0.8940  Index: 0.9731
# EI = -0.8272   Cross fraction = 0.9136
#
# [rete reale] Step 148
#  Changed: 966  Satisfaction: 0.8985  Index: 0.9749
# EI = -0.8278   Cross fraction = 0.9139
#
# [rete reale] Step 149
#  Changed: 978  Satisfaction: 0.8973  Index: 0.9747
# EI = -0.8282   Cross fraction = 0.9141
#
# [rete reale] Step 150
#  Changed: 981  Satisfaction: 0.8969  Index: 0.9751
# EI = -0.8290   Cross fraction = 0.9145
#
# [rete reale] Step 151
#  Changed: 950  Satisfaction: 0.9002  Index: 0.9760
# EI = -0.8298   Cross fraction = 0.9149
#
# [rete reale] Step 152
#  Changed: 975  Satisfaction: 0.8976  Index: 0.9745
# EI = -0.8307   Cross fraction = 0.9154
#
# [rete reale] Step 153
#  Changed: 906  Satisfaction: 0.9048  Index: 0.9764
# EI = -0.8316   Cross fraction = 0.9158
#
# [rete reale] Step 154
#  Changed: 946  Satisfaction: 0.9006  Index: 0.9752
# EI = -0.8316   Cross fraction = 0.9158
#
# [rete reale] Step 155
#  Changed: 937  Satisfaction: 0.9016  Index: 0.9772
# EI = -0.8319   Cross fraction = 0.9160
#
# [rete reale] Step 156
#  Changed: 907  Satisfaction: 0.9047  Index: 0.9768
# EI = -0.8324   Cross fraction = 0.9162
#
# [rete reale] Step 157
#  Changed: 947  Satisfaction: 0.9005  Index: 0.9758
# EI = -0.8329   Cross fraction = 0.9165
#
# [rete reale] Step 158
#  Changed: 929  Satisfaction: 0.9024  Index: 0.9767
# EI = -0.8330   Cross fraction = 0.9165
#
# [rete reale] Step 159
#  Changed: 898  Satisfaction: 0.9057  Index: 0.9767
# EI = -0.8336   Cross fraction = 0.9168
#
# [rete reale] Step 160
#  Changed: 958  Satisfaction: 0.8994  Index: 0.9761
# EI = -0.8342   Cross fraction = 0.9171
#
# [rete reale] Step 161
#  Changed: 903  Satisfaction: 0.9051  Index: 0.9776
# EI = -0.8351   Cross fraction = 0.9175
#
# [rete reale] Step 162
#  Changed: 930  Satisfaction: 0.9023  Index: 0.9772
# EI = -0.8359   Cross fraction = 0.9180
#
# [rete reale] Step 163
#  Changed: 936  Satisfaction: 0.9017  Index: 0.9769
# EI = -0.8366   Cross fraction = 0.9183
#
# [rete reale] Step 164
#  Changed: 892  Satisfaction: 0.9063  Index: 0.9777
# EI = -0.8371   Cross fraction = 0.9186
#
# [rete reale] Step 165
#  Changed: 928  Satisfaction: 0.9025  Index: 0.9758
# EI = -0.8375   Cross fraction = 0.9187
#
# [rete reale] Step 166
#  Changed: 917  Satisfaction: 0.9037  Index: 0.9773
# EI = -0.8380   Cross fraction = 0.9190
#
# [rete reale] Step 167
#  Changed: 915  Satisfaction: 0.9039  Index: 0.9759
# EI = -0.8383   Cross fraction = 0.9192
#
# [rete reale] Step 168
#  Changed: 931  Satisfaction: 0.9022  Index: 0.9750
# EI = -0.8390   Cross fraction = 0.9195
#
# [rete reale] Step 169
#  Changed: 869  Satisfaction: 0.9087  Index: 0.9766
# EI = -0.8394   Cross fraction = 0.9197
#
# [rete reale] Step 170
#  Changed: 891  Satisfaction: 0.9064  Index: 0.9766
# EI = -0.8397   Cross fraction = 0.9199
#
# [rete reale] Step 171
#  Changed: 937  Satisfaction: 0.9016  Index: 0.9763
# EI = -0.8403   Cross fraction = 0.9201
#
# [rete reale] Step 172
#  Changed: 904  Satisfaction: 0.9050  Index: 0.9760
# EI = -0.8407   Cross fraction = 0.9204
#
# [rete reale] Step 173
#  Changed: 901  Satisfaction: 0.9053  Index: 0.9767
# EI = -0.8411   Cross fraction = 0.9206
#
# [rete reale] Step 174
#  Changed: 878  Satisfaction: 0.9078  Index: 0.9770
# EI = -0.8418   Cross fraction = 0.9209
#
# [rete reale] Step 175
#  Changed: 895  Satisfaction: 0.9060  Index: 0.9780
# EI = -0.8424   Cross fraction = 0.9212
#
# [rete reale] Step 176
#  Changed: 902  Satisfaction: 0.9052  Index: 0.9778
# EI = -0.8428   Cross fraction = 0.9214
#
# [rete reale] Step 177
#  Changed: 922  Satisfaction: 0.9031  Index: 0.9761
# EI = -0.8434   Cross fraction = 0.9217
#
# [rete reale] Step 178
#  Changed: 897  Satisfaction: 0.9058  Index: 0.9784
# EI = -0.8437   Cross fraction = 0.9219
#
# [rete reale] Step 179
#  Changed: 905  Satisfaction: 0.9049  Index: 0.9761
# EI = -0.8443   Cross fraction = 0.9221
#
# [rete reale] Step 180
#  Changed: 939  Satisfaction: 0.9014  Index: 0.9764
# EI = -0.8446   Cross fraction = 0.9223
#
# [rete reale] Step 181
#  Changed: 891  Satisfaction: 0.9064  Index: 0.9768
# EI = -0.8453   Cross fraction = 0.9226
#
# [rete reale] Step 182
#  Changed: 854  Satisfaction: 0.9103  Index: 0.9774
# EI = -0.8457   Cross fraction = 0.9228
#
# [rete reale] Step 183
#  Changed: 898  Satisfaction: 0.9057  Index: 0.9774
# EI = -0.8459   Cross fraction = 0.9230
#
# [rete reale] Step 184
#  Changed: 867  Satisfaction: 0.9089  Index: 0.9770
# EI = -0.8465   Cross fraction = 0.9232
#
# [rete reale] Step 185
#  Changed: 873  Satisfaction: 0.9083  Index: 0.9772
# EI = -0.8471   Cross fraction = 0.9236
#
# [rete reale] Step 186
#  Changed: 850  Satisfaction: 0.9107  Index: 0.9788
# EI = -0.8479   Cross fraction = 0.9239
#
# [rete reale] Step 187
#  Changed: 866  Satisfaction: 0.9090  Index: 0.9785
# EI = -0.8485   Cross fraction = 0.9243
#
# [rete reale] Step 188
#  Changed: 886  Satisfaction: 0.9069  Index: 0.9773
# EI = -0.8496   Cross fraction = 0.9248
#
# [rete reale] Step 189
#  Changed: 852  Satisfaction: 0.9105  Index: 0.9787
# EI = -0.8500   Cross fraction = 0.9250
#
# [rete reale] Simulazione fermata a satisfaction rate: 91.0%

# %% [markdown]
# ## Null model Erdős-Rényi
#
# Per valutare se la dinamica osservata è una proprietà intrinseca del meccanismo di rewire o dipende dalla struttura della rete di partenza, confrontiamo con un **null model di Erdős-Rényi**.
#
# Il modello ER viene inizializzato con:
# - $n$ nodi — stesso numero della rete reale
# - probabilità $p = m / \binom{n}{2}$ — tale da avere in media lo stesso numero di archi
# - comunità assegnate **casualmente** ai nodi, con le stesse dimensioni delle comunità reali

# %%
def build_er_null_model(G_real, seed=None):
    """Costruisce un grafo Erdős-Rényi con le stesse proprietà di base della rete reale
    e comunità assegnate casualmente con la stessa distribuzione.
    G_real : grafo reale
    seed   : seme random
    Return : grafo ER
    """
    if seed is not None:
        np.random.seed(seed)

    n = G_real.vcount()
    m = G_real.ecount()
    p = m / (n * (n - 1) / 2)

    # Grafo ER con probabilità calibrata
    G_er = ig.Graph.Erdos_Renyi(n=n, p=p)

    # Assegnazione random delle comunità rispettando le dimensioni originali
    group_labels_real = np.array(G_real.vs['group'])
    shuffled_groups   = np.random.permutation(group_labels_real)
    G_er.vs['group']  = shuffled_groups.tolist()

    return G_er


G_er = build_er_null_model(G, seed=42)

# %%
G_er = G_er.connected_components().giant()
print('G_er è stato connesso con perdita di:',  G.vcount() - G_er.vcount(), 'nodi')
if G.vcount() - G_er.vcount() > 20:
    print('Attenzione!')
# Out:
# G_er è stato connesso con perdita di: 1 nodi

# %%
results_er = run_simulation(G_er, THRESHOLD, label='Erdős-Rényi', max_satisfaction=satisfaction_rate_obs)
# Out:
# [Erdős-Rényi] target : EI = -0.9340   Cross fraction = 0.9670
#
# [Erdős-Rényi] Simulazione avviata:  EI = -0.0079   Cross fraction = 0.5040
#
# [Erdős-Rényi] Step 1
#  Changed: 9183  Satisfaction: 0.0352  Index: 0.5556
# EI = -0.0086   Cross fraction = 0.5043
#
# [Erdős-Rényi] Step 2
#  Changed: 8148  Satisfaction: 0.1439  Index: 0.7140
# EI = -0.0067   Cross fraction = 0.5034
#
# [Erdős-Rényi] Step 3
#  Changed: 7052  Satisfaction: 0.2591  Index: 0.8037
# EI = -0.0099   Cross fraction = 0.5049
#
# [Erdős-Rényi] Step 4
#  Changed: 5988  Satisfaction: 0.3709  Index: 0.8546
# EI = -0.0136   Cross fraction = 0.5068
#
# [Erdős-Rényi] Step 5
#  Changed: 5187  Satisfaction: 0.4550  Index: 0.8871
# EI = -0.0155   Cross fraction = 0.5078
#
# [Erdős-Rényi] Step 6
#  Changed: 4558  Satisfaction: 0.5211  Index: 0.9087
# EI = -0.0138   Cross fraction = 0.5069
#
# [Erdős-Rényi] Step 7
#  Changed: 4051  Satisfaction: 0.5744  Index: 0.9243
# EI = -0.0150   Cross fraction = 0.5075
#
# [Erdős-Rényi] Step 8
#  Changed: 3609  Satisfaction: 0.6208  Index: 0.9352
# EI = -0.0163   Cross fraction = 0.5081
#
# [Erdős-Rényi] Step 9
#  Changed: 3260  Satisfaction: 0.6575  Index: 0.9443
# EI = -0.0136   Cross fraction = 0.5068
#
# [Erdős-Rényi] Step 10
#  Changed: 2889  Satisfaction: 0.6965  Index: 0.9508
# EI = -0.0167   Cross fraction = 0.5084
#
# [Erdős-Rényi] Step 11
#  Changed: 2621  Satisfaction: 0.7246  Index: 0.9568
# EI = -0.0159   Cross fraction = 0.5080
#
# [Erdős-Rényi] Step 12
#  Changed: 2419  Satisfaction: 0.7458  Index: 0.9622
# EI = -0.0122   Cross fraction = 0.5061
#
# [Erdős-Rényi] Step 13
#  Changed: 2232  Satisfaction: 0.7655  Index: 0.9650
# EI = -0.0133   Cross fraction = 0.5067
#
# [Erdős-Rényi] Step 14
#  Changed: 2072  Satisfaction: 0.7823  Index: 0.9686
# EI = -0.0105   Cross fraction = 0.5053
#
# [Erdős-Rényi] Step 15
#  Changed: 1867  Satisfaction: 0.8038  Index: 0.9720
# EI = -0.0137   Cross fraction = 0.5068
#
# [Erdős-Rényi] Step 16
#  Changed: 1742  Satisfaction: 0.8170  Index: 0.9740
# EI = -0.0119   Cross fraction = 0.5060
#
# [Erdős-Rényi] Step 17
#  Changed: 1589  Satisfaction: 0.8331  Index: 0.9764
# EI = -0.0120   Cross fraction = 0.5060
#
# [Erdős-Rényi] Step 18
#  Changed: 1510  Satisfaction: 0.8414  Index: 0.9772
# EI = -0.0130   Cross fraction = 0.5065
#
# [Erdős-Rényi] Step 19
#  Changed: 1434  Satisfaction: 0.8493  Index: 0.9784
# EI = -0.0129   Cross fraction = 0.5064
#
# [Erdős-Rényi] Step 20
#  Changed: 1329  Satisfaction: 0.8604  Index: 0.9804
# EI = -0.0117   Cross fraction = 0.5059
#
# [Erdős-Rényi] Step 21
#  Changed: 1327  Satisfaction: 0.8606  Index: 0.9804
# EI = -0.0100   Cross fraction = 0.5050
#
# [Erdős-Rényi] Step 22
#  Changed: 1164  Satisfaction: 0.8777  Index: 0.9829
# EI = -0.0082   Cross fraction = 0.5041
#
# [Erdős-Rényi] Step 23
#  Changed: 1139  Satisfaction: 0.8803  Index: 0.9834
# EI = -0.0109   Cross fraction = 0.5055
#
# [Erdős-Rényi] Step 24
#  Changed: 1084  Satisfaction: 0.8861  Index: 0.9847
# EI = -0.0097   Cross fraction = 0.5049
#
# [Erdős-Rényi] Step 25
#  Changed: 1012  Satisfaction: 0.8937  Index: 0.9855
# EI = -0.0096   Cross fraction = 0.5048
#
# [Erdős-Rényi] Step 26
#  Changed: 992  Satisfaction: 0.8958  Index: 0.9858
# EI = -0.0121   Cross fraction = 0.5061
#
# [Erdős-Rényi] Step 27
#  Changed: 943  Satisfaction: 0.9009  Index: 0.9863
# EI = -0.0140   Cross fraction = 0.5070
#
# [Erdős-Rényi] Step 28
#  Changed: 921  Satisfaction: 0.9032  Index: 0.9868
# EI = -0.0132   Cross fraction = 0.5066
#
# [Erdős-Rényi] Step 29
#  Changed: 880  Satisfaction: 0.9075  Index: 0.9872
# EI = -0.0130   Cross fraction = 0.5065
#
# [Erdős-Rényi] Simulazione fermata a satisfaction rate: 90.8%

# %%
dump = {
    'file':       GRAPH_FILE,
    'threshold':  THRESHOLD,
    'observed':   observed,
    'sim_real':   results_real,
    'sim_er':     results_er,
}

with open(OUT_PATH, 'w') as f:
    json.dump(dump, f, indent=2)

print(f'Risultati salvati in: {OUT_PATH}')
# Out:
# Risultati salvati in: dump_segregation_immigration_23_95.json

# %% [markdown]
# ## Visualizzazione: simulazione vs osservato vs null model ER

# %%
def plot_comparison(results: dict):
    """Genera la figura di confronto tra simulazione reale, ER e valori osservati."""
    observed = results['observed']
    results_real = results['sim_real']
    results_er = results['sim_er']
    threshold = results['threshold']
    metrics = ['ei_index', 'cross_fraction', 'satisfaction_rate', 'segregation_index']
    titles  = ['EI Index', 'Cross Fraction', 'Satisfaction Rate', 'Segregation Index']

    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle(
        f'Confronto Simulazione Segregazione vs Null Model ER — soglia = {threshold}',
        fontsize=14, fontweight='bold'
    )

    for ax, metric, title in zip(axes.flat, metrics, titles):
        t_real = range(len(results_real[metric]))
        t_er   = range(len(results_er[metric]))

        ax.plot(t_real, results_real[metric], label='Sim. rete reale',  color='steelblue', linewidth=2)
        ax.plot(t_er,   results_er[metric],   label='Sim. Erdős-Rényi', color='darkorange', linewidth=2)
        ax.axhline(observed[metric], color='crimson', linestyle=':', linewidth=1.5,
                   label=f'Osservato = {observed[metric]:.3f}')
        ax.axvline(len(results_er['ei_index'])-1, linestyle='--', color='grey', alpha=0.5)
        ax.set_title(title, fontsize=12)
        ax.set_xlabel('Step')
        ax.set_ylabel(title)
        ax.legend(fontsize=9)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()
    return fig

# %%
results_all = [json.load(open(dump_name)) 
                for dump_name in 
                ['dump_segregation_immigration_23_35.json', 'dump_segregation_immigration_23_65.json', 'dump_segregation_immigration_23_95.json']]
for result in results_all:
    plot_comparison(result)

# %% [markdown]
# ## Analisi del valore finale a regime
#
# Confronto dei valori finali tra la simulazione sulla rete reale e quella sul null model ER.

# %%
fig2, ax = plt.subplots(figsize=(12, 5))

# plot risultati al variare della soglia simulata: 0.35, 0.65, 0.95
x = np.arange(len(results_all))
# Barchart di confronto a regime
width  = 0.25
bars_obs  = ax.bar(x - width,  [sim_result['observed']['cross_fraction']   for sim_result in results_all],
                    width, label='Osservato',       color='crimson',    alpha=0.8)
bars_real = ax.bar(x,          [sim_result['sim_real']['cross_fraction'][-1]    for sim_result in results_all],
                    width, label='Sim. Rete Reale', color='steelblue',  alpha=0.8)
bars_er   = ax.bar(x + width,  [sim_result['sim_er']['cross_fraction'][-1]    for sim_result in results_all],
                    width, label='Sim. ER',         color='darkorange', alpha=0.8)

ax.axhline(0.5, color='black', linestyle='--', alpha=0.65, label='random cross fraction')
ax.set_xticks(x)
ax.set_xticklabels([str(result_sim['threshold']) for result_sim in results_all])
ax.set_ylabel('Cross Fraction a regime')
ax.set_xlabel('Soglie simulate')
ax.set_title(f'Valori finali a regime', fontsize=13)
ax.legend(frameon = False, bbox_to_anchor=(1.3,1), loc='upper right')
ax.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Conclusioni
#
# Osserviamo come la simulazione converga ad uno stato stazionario ad ogni iterazione indipendentemente dalla soglia, riuscendo quindi a soddisfare tutti i nodi.
#
# Per un'ampia scelta di valori della soglia di soddisfazione $[0.35, 0.75]$ il valore finale dell'indice di segregazione rimane costantemente alto intorno all'$80\%$. Mentre per essere in grado di riprodurre i valori osservati per tutte le metriche di controllo è necessario impostare una soglia molto alta di almeno $95\%$.
#
# Concludiamo che il valore di polarizzazione osservato nella rete (**EI index** o **cross fraction**) può essere spiegaato da:
# - fenomeni non descritti dal modello, ad esempio l'organizzazione in gruppi politici strutturati;
# - gli utenti hanno effettivamente una forte tendenza a ricerare individui simili a loro.
#
# Il confronto con il **null model Erdős-Rényi** permette di valutare che la polarizzazione osservata non è una proprietà emergente dal meccanismo di rewire soltanto, ma ha una forte dipendenza dalla topologia di partenza.
